# %%
# import the packages
# read the data

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as  sns

visa_df=pd.read_csv(r"C:\Users\sathish\Documents\datafiles\visadataset.csv")

cat_columns=visa_df.select_dtypes(include='object').columns
num_columns=visa_df.select_dtypes(exclude='object').columns

# %%
visa_df=pd.read_csv(r"C:\Users\sathish\Documents\datafiles\visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %% [markdown]
# **Bi variate analysis**
#
# - we already seen uni-variate analysis
#
# - we performed the categorical columns analysis
#
#     - frequency table (value counts)
#
#     - bar chart
#
#     - relative frequency table (value counts normalized form)
#
#     - pie chart
#
# - we performed the numerical columns analysis
#
#     - histogram
#
#     - distribution plots
#
#     - Box plot
#
#     - outliers analysis
#
#     - filling the outliers
#
# - now we will do caterogical - catergorical analysis
#
# - numerical-numerical analysis
#
# - categorical-numerical analysis

# %% [markdown]
# **caterogical - catergorical**
#
# - lets consider two columns
#
#     - continent
#
#     - case status

# %%
# continent 
# aug 7th video second half 
# i will clean up

visa_df['continent'].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
visa_df['case_status'].value_counts()
# Out:
# case_status
# Certified    17018
# Denied        8462
# Name: count, dtype: int64

# %% [markdown]
# **Task**
#
# - find the certified observations continent wise
#
# - find the denied observations continent wise

# %%
# step-1: make the first condition continent==='asia'
# step-2: make the second condition case_status=='certified'
# step-3: make the third condition : con1&con2
# step-4: then retrive the dataframe and take the count

# %%
con1=visa_df['continent']=='Asia'
con2=visa_df['case_status']=='Certified'
con3=con1&con2
len(visa_df[con3])
# Out:
# 11012

# %%
visa_df['continent'].unique()
visa_df['continent'].value_counts().keys()
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
continents=visa_df['continent'].unique()
certified_list=[]
for i in continents:
    con1=visa_df['continent']==i
    con2=visa_df['case_status']=='Certified'
    con3=con1&con2
    count=len(visa_df[con3])
    print(f"the number of certified visa from (i) is: {count}")
    certified_list.append(count)
# Out:
# the number of certified visa from (i) is: 11012
# the number of certified visa from (i) is: 397
# the number of certified visa from (i) is: 2037
# the number of certified visa from (i) is: 2957
# the number of certified visa from (i) is: 493
# the number of certified visa from (i) is: 122

# %%
continents=visa_df['continent'].unique()
certified_list,denied_list=[],[]
for i in continents:
    con1=visa_df['continent']==i
    con2=visa_df['case_status']=='certified'
    con3=visa_df['case_status']=='Denied'
    cert_con=con1&con2
    den_con=con1&con3
    cert_count=len(visa_df[cert_con])
    den_count=len(visa_df[den_con])
    print(f"the number of certified visa from (i) is: {cert_count}")
    print(f"the number of certified visa from (i) is: {den_count}")
    certified_list.append(cert_count)
    certified_list.append(den_count)
# Out:
# the number of certified visa from (i) is: 0
# the number of certified visa from (i) is: 5849
# the number of certified visa from (i) is: 0
# the number of certified visa from (i) is: 154
# the number of certified visa from (i) is: 0
# the number of certified visa from (i) is: 1255
# the number of certified visa from (i) is: 0
# the number of certified visa from (i) is: 775
# the number of certified visa from (i) is: 0
# the number of certified visa from (i) is: 359
# the number of certified visa from (i) is: 0
# the number of certified visa from (i) is: 70

# %%
# DF
continents
certified_list
cols=['continents','certified']
df1=pd.DataFrame(zip(continents,certified_list),
                 columns=cols)
df1
# Out:
#       continents  certified
# 0           Asia          0
# 1         Africa       5849
# 2  North America          0
# 3         Europe        154
# 4  South America          0
# 5        Oceania       1255

# %%
cols=['continents','certified']
df2=pd.DataFrame(zip(continents,denied_list),
                 columns=cols)
df2
# Out:
# Empty DataFrame
# Columns: [continents, certified]
# Index: []

# %%
cols=['continents','Denied']
df3=pd.DataFrame(zip(continents,denied_list),
                 index=denie,
                 columns=cols)
df3
# Out:
# Empty DataFrame
# Columns: [continents, Denied]
# Index: []

# %% [markdown]
# **Cross tab**
#
# - the above dtat frame we can make by using a method: **cross tab**
#
# - it is available in pandas
#
# - it is two argument
#
#     - index
#
#     - columns
#
# - in above data frame index column is : **continent**
#
# - in above data frame data column is : **case_status**

# %%
pd.crosstab(visa_df['continent'],visa_df['case_status'])
# Out:
# case_status    Certified  Denied
# continent
# Africa               397     154
# Asia               11012    5849
# Europe              2957     775
# North America       2037    1255
# Oceania              122      70
# South America        493     359

# %%
idx_column=visa_df['continent']
data_column=visa_df['case_status']
df4=pd.crosstab(idx_column,data_column)
df4
# Out:
# case_status    Certified  Denied
# continent
# Africa               397     154
# Asia               11012    5849
# Europe              2957     775
# North America       2037    1255
# Oceania              122      70
# South America        493     359

# %%
df4.plot(kind='bar')
# Out:
# <Axes: xlabel='continent'>

# %% [markdown]
# **Multivariate analysis**
#
# - education
#
# - continent
#
# - case status
#
# - we already know from asia there 11k accepted visa
#
# - in thet i want future break down on education
#
# - here also pd.cross tab
#
#     - first your index of any one column out of three column
#
#     - then keep two column in a list and pass as data column

# %%
idx_column=visa_df['continent']
data_column=[visa_df['education_of_employee'],
            visa_df['case_status']]
df5=pd.crosstab(idx_column,data_column)
df5
# Out:
# education_of_employee Bachelor's        Doctorate        High School         \
# case_status            Certified Denied Certified Denied   Certified Denied
# continent
# Africa                        81     62        43     11          23     43
# Asia                        4407   2761       780    143         676   1614
# Europe                      1040    259       788     58         162    328
# North America                641    584       207     51         210    191
# Oceania                       38     28        19      3          19     17
# South America                160    173        75     14          74     63
#
# education_of_employee  Master's
# case_status           Certified Denied
# continent
# Africa                      250     38
# Asia                       5149   1331
# Europe                      967    130
# North America               979    429
# Oceania                      46     22
# South America               184    109

# %%
df5.plot(kind='bar')
# Out:
# <Axes: xlabel='continent'>

# %%
# import the packages
# read the data
# divide into cat and num

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as  sns

visa_df=pd.read_csv(r"C:\Users\sathish\Documents\datafiles\visadataset.csv")

cat_columns=visa_df.select_dtypes(include='object').columns
num_columns=visa_df.select_dtypes(exclude='object').columns

# %% [markdown]
# **Numerical vs Numerical**

# %% [markdown]
# - to understand Numerical columns relation we need to plot scatter plots
#
# - scatter plots gives the relation between two numerical columns
#
# - Bar chart - pie chart - histogram - scatter plots
#
# - scatters plot under matplotlib package
#
# - **plt.scatter**

# %%
x=[1,2,3,4,5]
y=[1,2,3,4,5]
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %%
x=[i for i in range(-10,11)]
y=[i*i for i in x]
plt.scatter(x,y)

# %%
x=[i for i in range(-10,11)]
y=[i*i for i in x]
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %%
y
# Out:
# [100, 81, 64, 49, 36, 25, 16, 9, 4, 1, 0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
pd.DataFrame(x,y

# %%
# step-1: read one numerical column
# step-2: read another numerical  column
# apply the scatter plot

# %%
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
col1=visa_df['no_of_employees']
col2=visa_df['yr_of_estab']
plt.scatter(col1,col2)

# %%
col1=visa_df['no_of_employees']
col2=visa_df['yr_of_estab']
col3=visa_df['prevailing_wage']
plt.figure(figsize=(14,3))
plt.subplot(1,3,1).scatter(col1,col2)
plt.xlabel('no_of_employees')
plt.ylabel('yr_of_estab')
###########################################
plt.subplot(1,3,2).scatter(col1,col3)
plt.xlabel('no_of_employees')
plt.ylabel('prevailing_wage')
###############################################
plt.subplot(1,3,3).scatter(col1,col3)
plt.xlabel('no_of_employees')
plt.ylabel('prevailing_wage')
# Out:
# Text(0, 0.5, 'prevailing_wage')

# %% [markdown]
# - implement the covariance function
#
# - covariance vs correlation
#
#     - covariance will tell about the columns have relation or not
#
#     - covariance will explain about relation status
#
#         - postive relation
#
#         - negative relation
#
#         - no relation
#
#     - correlation tells about how much relation between two variables
#
#     - it denotes with 'r'
#
#     - r variance from -1 to 1
#
#     - -1 to 0 indicates negative relation quantity
#
#     - 0 to 1 indicates positive relation quantity
#
#     - o indicates no relation

# %% [markdown]
# **method name : corr**

# %%
visa_df.corr(numeric_only=True)
# Out:
#                  no_of_employees  yr_of_estab  prevailing_wage
# no_of_employees         1.000000    -0.017770        -0.009523
# yr_of_estab            -0.017770     1.000000         0.012342
# prevailing_wage        -0.009523     0.012342         1.000000

# %% [markdown]
# **Heat map**
#
# - Heat map is one of the import visualization methpd , to show the matrix from
#
# - it is under **seaborn** package
#
# - in every matrix we ave heighes values and lowest values avaialble
#
# - Heat map will give colour visulization
#
# - also it provides colour bar, which colour indicates which value

# %%
corr_data=visa_df.corr(numeric_only=True)
sns.heatmap(corr_data,annot=True)
plt.show()

# %%
corr_data=visa_df.corr(numeric_only=True)
sns.heatmap(corr_data,annot=True,cmap='Greens')
plt.show()

# %%
corr_data=visa_df.corr(numeric_only=True)
sns.heatmap(corr_data,annot=True,cmap='magma')
plt.show()

# %% [markdown]
# - By seeing the graphs we might not say the relation status
#
# - it is best practice get the percentage of relation using correlation
#
# - all 3 columns having approximately zero percentage of relation
#
# - which indicates all the columns having no relation
#
# - no relation means independent each other
#
# - in ML we expect the input columns should be indepent each other
#
# - corr method gives matrix view
#
# - we have 3 columns 3*3 total 9 fields
#
# - if a data has 20 columns then 20*20 total 400 fields
#
# - thats why always go with heat map visulazation
